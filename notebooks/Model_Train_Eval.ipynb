# %% [markdown]
# # Model Training and Evaluation on Bike Data

# %% [markdown]
# ### Imports

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.preprocessing import OneHotEncoder

from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsRegressor

from xgboost import XGBRegressor
import lightgbm as lgb

from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso

from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

import pickle
import os

# %%
df = pd.read_csv("../data/SeoulBikeData.csv", encoding="latin1")

# %% [markdown]
# ### Preprocessing

# %%
df
# Out:
#             Date  Rented Bike Count  Hour  Temperature(°C)  Humidity(%)  \
# 0     01/12/2017                254     0             -5.2           37
# 1     01/12/2017                204     1             -5.5           38
# 2     01/12/2017                173     2             -6.0           39
# 3     01/12/2017                107     3             -6.2           40
# 4     01/12/2017                 78     4             -6.0           36
# ...          ...                ...   ...              ...          ...
# 8755  30/11/2018               1003    19              4.2           34
# 8756  30/11/2018                764    20              3.4           37
# 8757  30/11/2018                694    21              2.6           39
# 8758  30/11/2018                712    22              2.1           41
# 8759  30/11/2018                584    23              1.9           43
#
#       Wind speed (m/s)  Visibility (10m)  Dew point temperature(°C)  \
# ...

# %%
def preprocess(df):
    df["Date"] = pd.to_datetime(df["Date"], dayfirst=True)
    df["Month"] = df["Date"].dt.month
    df.drop("Date", axis=1, inplace=True)
    df.drop("Seasons", axis=1, inplace=True)
    df["Holiday"] = df["Holiday"].map({"Holiday": 1, "No Holiday": 0})
    df["Functioning Day"] = df["Functioning Day"].map({"Yes": 1, "No": 0})
    return df

# %%
df = preprocess(df)
df
# Out:
#       Rented Bike Count  Hour  Temperature(°C)  Humidity(%)  Wind speed (m/s)  \
# 0                   254     0             -5.2           37               2.2
# 1                   204     1             -5.5           38               0.8
# 2                   173     2             -6.0           39               1.0
# 3                   107     3             -6.2           40               0.9
# 4                    78     4             -6.0           36               2.3
# ...                 ...   ...              ...          ...               ...
# 8755               1003    19              4.2           34               2.6
# 8756                764    20              3.4           37               2.3
# 8757                694    21              2.6           39               0.3
# 8758                712    22              2.1           41               1.0
# 8759                584    23              1.9           43               1.3
#
# ...

# %%
# Separate Features and Target
X = df.drop(columns=["Rented Bike Count"])
y = df["Rented Bike Count"]

# Apply Log Transformation to Target
y_log = np.log1p(y)

X_train, X_test, y_train_log, y_test_log = train_test_split(
    X, y_log, test_size=0.2, random_state=42
)

# %%
df.columns
# Out:
# Index(['Rented Bike Count', 'Hour', 'Temperature(°C)', 'Humidity(%)',
#        'Wind speed (m/s)', 'Visibility (10m)', 'Dew point temperature(°C)',
#        'Solar Radiation (MJ/m2)', 'Rainfall(mm)', 'Snowfall (cm)', 'Holiday',
#        'Functioning Day', 'Month'],
#       dtype='object')

# %% [markdown]
# ### Model Training

# %%
knn_pipeline = Pipeline([
    ("scaler", StandardScaler()),
    ("knn", KNeighborsRegressor())
])

param_grid = {
    "knn__n_neighbors": [3, 5, 7, 9],
    "knn__weights": ["uniform", "distance"],
    "knn__p": [1, 2]
}

knn_gs = GridSearchCV(
    knn_pipeline,
    param_grid,
    cv=5,
    scoring="neg_mean_squared_error",
    n_jobs=-1
)

knn_gs.fit(X_train, y_train_log)
# Out:
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('scaler', StandardScaler()),
#                                        ('knn', KNeighborsRegressor())]),
#              n_jobs=-1,
#              param_grid={'knn__n_neighbors': [3, 5, 7, 9], 'knn__p': [1, 2],
#                          'knn__weights': ['uniform', 'distance']},
#              scoring='neg_mean_squared_error')

# %%
#Ridge Regression
ridge_pipeline = Pipeline([
    ("scaler", StandardScaler()),
    ("ridge", Ridge())
])

ridge_params = {
    "ridge__alpha": [0.01, 0.1, 1, 10, 100]
}

ridge_gs = GridSearchCV(
    ridge_pipeline,
    ridge_params,
    cv=5,
    scoring="neg_mean_squared_error"
)

ridge_gs.fit(X_train, y_train_log)
# Out:
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('scaler', StandardScaler()),
#                                        ('ridge', Ridge())]),
#              param_grid={'ridge__alpha': [0.01, 0.1, 1, 10, 100]},
#              scoring='neg_mean_squared_error')

# %%
#Lasso Regression
lasso_pipeline = Pipeline([
    ("scaler", StandardScaler()),
    ("lasso", Lasso(max_iter=10000))
])

lasso_params = {
    "lasso__alpha": [0.001, 0.01, 0.1, 1, 10]
}

lasso_gs = GridSearchCV(
    lasso_pipeline,
    lasso_params,
    cv=5,
    scoring="neg_mean_squared_error"
)

lasso_gs.fit(X_train, y_train_log)
# Out:
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('scaler', StandardScaler()),
#                                        ('lasso', Lasso(max_iter=10000))]),
#              param_grid={'lasso__alpha': [0.001, 0.01, 0.1, 1, 10]},
#              scoring='neg_mean_squared_error')

# %%
#Linear Regression
linear_pipeline = Pipeline([
    ("scaler", StandardScaler()),
    ("linreg", LinearRegression())
])

linear_pipeline.fit(X_train, y_train_log)
# Out:
# Pipeline(steps=[('scaler', StandardScaler()), ('linreg', LinearRegression())])

# %%
rf_params = {
    "n_estimators": [100, 200],
    "max_depth": [None, 10, 20],
    "min_samples_split": [2, 5]
}

rf_gs = GridSearchCV(
    RandomForestRegressor(random_state=42),
    rf_params,
    cv=5,
    scoring="neg_mean_squared_error",
    n_jobs=-1
)

rf_gs.fit(X_train, y_train_log)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestRegressor(random_state=42), n_jobs=-1,
#              param_grid={'max_depth': [None, 10, 20],
#                          'min_samples_split': [2, 5],
#                          'n_estimators': [100, 200]},
#              scoring='neg_mean_squared_error')

# %%
# Define the parameter grid for XGBoost
xgb_params = {
    "n_estimators": [500, 1000],
    "max_depth": [6, 8, 10],
    "learning_rate": [0.01, 0.05, 0.1],
    "subsample": [0.8, 1.0],
    "colsample_bytree": [0.8, 1.0]
}

# Initialize the GridSearchCV
xgb_gs = GridSearchCV(
    XGBRegressor(random_state=42, objective='reg:squarederror'),
    xgb_params,
    cv=5,
    scoring="neg_mean_squared_error",
    n_jobs=-1,
    verbose=1
)

# Fit the model
xgb_gs.fit(X_train, y_train_log)
# Out:
# Fitting 5 folds for each of 72 candidates, totalling 360 fits
# GridSearchCV(cv=5,
#              estimator=XGBRegressor(base_score=None, booster=None,
#                                     callbacks=None, colsample_bylevel=None,
#                                     colsample_bynode=None,
#                                     colsample_bytree=None, device=None,
#                                     early_stopping_rounds=None,
#                                     enable_categorical=False, eval_metric=None,
#                                     feature_types=None, feature_weights=None,
#                                     gamma=None, grow_policy=None,
#                                     importance_type=None,
#                                     interaction_constraints=None...
#                                     max_depth=None, max_leaves=None,
#                                     min_child_weight=None, missing=nan,
# ...

# %%
# LightGBM parameters
lgbm_params = {
    "n_estimators": [500, 1000],
    "learning_rate": [0.01, 0.05, 0.1],
    "num_leaves": [31, 63, 127],         # Controls tree complexity
    "subsample": [0.8, 1.0],
    "colsample_bytree": [0.8, 1.0]
}

# Initialize the model
# Use 'regression' for bike counts
lgbm_gs = GridSearchCV(
    lgb.LGBMRegressor(random_state=42, objective='regression'),
    lgbm_params,
    cv=5,
    scoring="neg_mean_squared_error",
    n_jobs=-1,
    verbose=1
)

# Fit the model
lgbm_gs.fit(X_train, y_train_log)

# Best results
print(f"Best Parameters: {lgbm_gs.best_params_}")
print(f"Best Score (MSE): {-lgbm_gs.best_score_}")
# Out:
# Fitting 5 folds for each of 72 candidates, totalling 360 fits
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000827 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1260
# [LightGBM] [Info] Number of data points in the train set: 7008, number of used features: 12
# [LightGBM] [Info] Start training from score 5.884864
# Best Parameters: {'colsample_bytree': 1.0, 'learning_rate': 0.05, 'n_estimators': 500, 'num_leaves': 63, 'subsample': 0.8}
# Best Score (MSE): 0.15746890949078626

# %% [markdown]
# ### Evaluation

# %%
def evaluate_log_model(model, X_test, y_test_log):
    # Predict in log scale
    y_pred_log = model.predict(X_test)

    # Inverse transform to actual counts
    y_pred = np.expm1(y_pred_log)
    y_actual = np.expm1(y_test_log)

    # Calculate Metrics
    mse = mean_squared_error(y_actual, y_pred)
    rmse = np.sqrt(mse)
    mae = mean_absolute_error(y_actual, y_pred)
    r2 = r2_score(y_actual, y_pred)

    return mse, rmse, mae, r2

# %%
models = {
    "Linear Regression": linear_pipeline,
    "Ridge": ridge_gs.best_estimator_,
    "Lasso": lasso_gs.best_estimator_,
    "K Nearest Neighbors": knn_gs.best_estimator_,
    "Random Forest": rf_gs.best_estimator_,
    "LightGBM": lgbm_gs.best_estimator_,
    "XGBoost": xgb_gs.best_estimator_,

}

for name, model in models.items():
   mse, rmse, mae, r2 = evaluate_log_model(model, X_test, y_test_log)
   print(f"{name}")
   print(f" MSE: {mse:.2f}")
   print(f" RMSE: {rmse:.2f}")
   print(f" MAE: {mae:.2f}")
   print(f" R²: {r2:.4f}\n")
# Out:
# Linear Regression
#  MSE: 240392.03
#  RMSE: 490.30
#  MAE: 309.29
#  R²: 0.4230
#
# Ridge
#  MSE: 240103.23
#  RMSE: 490.00
#  MAE: 309.15
#  R²: 0.4237
#
# Lasso
#  MSE: 239240.59
#  RMSE: 489.12
#  MAE: 308.74
#  R²: 0.4258
#
# K Nearest Neighbors
#  MSE: 89352.73
#  RMSE: 298.92
#  MAE: 171.79
#  R²: 0.7855
#
# Random Forest
#  MSE: 61793.77
#  RMSE: 248.58
#  MAE: 141.15
#  R²: 0.8517
#
# LightGBM
#  MSE: 53868.87
#  RMSE: 232.10
#  MAE: 130.76
#  R²: 0.8707
#
# XGBoost
#  MSE: 51221.19
#  RMSE: 226.32
#  MAE: 126.97
#  R²: 0.8771

# %%
print("Best hyperparameters for XG Boost:", xgb_gs.best_params_)
# Out:
# Best hyperparameters for XG Boost: {'colsample_bytree': 1.0, 'learning_rate': 0.05, 'max_depth': 8, 'n_estimators': 500, 'subsample': 0.8}

# %% [markdown]
# - Linear, Lasso, Ridge Regressions can explain around 51% of variance
# - Regularization does not substantially improve predictve performance
# - Relationship between features and bike count is not well approximated by linear models
# - Random Forest and KNN outperformed the linear approaches with Random Forest performing the best
# - Nonlinear interactions are important in the data and RF can capture it better

# %% [markdown]
# ### Visualize Results

# %%
results = {
    "Model": [],
    "MSE": [],
    "RMSE": [],
    "MAE": [],
    "R2": []
}

for name, model in models.items():
    mse, rmse, mae, r2 = evaluate_log_model(model, X_test, y_test_log)
    results["Model"].append(name)
    results["MSE"].append(mse)
    results["RMSE"].append(rmse)
    results["MAE"].append(mae)
    results["R2"].append(r2)

# %%
results_df = pd.DataFrame(results)

# %%
plt.figure()
plt.bar(results_df["Model"], results_df["RMSE"])
plt.ylabel("RMSE")
plt.title("RMSE Comparison Across Models")
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure()
plt.bar(results_df["Model"], results_df["MAE"])
plt.ylabel("MAE")
plt.title("MAE Comparison Across Models")
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure()
plt.bar(results_df["Model"], results_df["R2"])
plt.ylabel("R²")
plt.title("R² Comparison Across Models")
plt.xticks(rotation=90)
plt.ylim(0, 1)
plt.show()

# %%
plt.figure()
plt.bar(results_df["Model"], results_df["RMSE"], label="RMSE")
plt.bar(results_df["Model"], results_df["MAE"], label="MAE", bottom=results_df["RMSE"])
plt.ylabel("Error")
plt.title("Error Metrics Comparison")
plt.xticks(rotation=90)
plt.legend()
plt.show()

# %% [markdown]
# ### Saving Trained Models

# %%
# Use ".." to step out of 'notebooks' and then into 'models'
folder_path = os.path.join("..", "models")

# Create it if it doesn't exist at the root level
if not os.path.exists(folder_path):
    os.makedirs(folder_path)


# Save models into that folder
# We use os.path.join for better compatibility across different operating systems
with open(os.path.join(folder_path, "linear.pkl"), "wb") as f:
    pickle.dump(linear_pipeline, f)

with open(os.path.join(folder_path, "lasso.pkl"), "wb") as f:
    pickle.dump(lasso_gs.best_estimator_, f)

with open(os.path.join(folder_path, "ridge.pkl"), "wb") as f:
    pickle.dump(ridge_gs.best_estimator_, f)

with open(os.path.join(folder_path, "rf.pkl"), "wb") as f:
    pickle.dump(rf_gs.best_estimator_, f)

with open(os.path.join(folder_path, "xgb.pkl"), "wb") as f:
    pickle.dump(xgb_gs.best_estimator_, f)

with open(os.path.join(folder_path, "lgbm.pkl"), "wb") as f:
    pickle.dump(lgbm_gs.best_estimator_, f)

with open(os.path.join(folder_path, "knn.pkl"), "wb") as f:
    pickle.dump(knn_gs.best_estimator_, f)
